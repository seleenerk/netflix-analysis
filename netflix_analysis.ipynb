# %%
import pandas as pd
df= pd.read_csv("netflix_titles.csv")
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# ...

# %%
df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df['director'].fillna('Unknown', inplace=True)
df['cast'].fillna('Unknown', inplace=True)
df['country'].fillna('Unknown', inplace=True)
df['rating'].fillna('Unknown', inplace=True)
df['duration'].fillna('Unknown', inplace=True)

df['date_added']= pd.to_datetime(df['date_added'], errors='coerce')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      8807 non-null   object
#  4   cast          8807 non-null   object
#  5   country       8807 non-null   object
#  6   date_added    8709 non-null   datetime64[ns]
#  7   release_year  8807 non-null   int64
#  8   rating        8807 non-null   object
#  9   duration      8807 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(10)
# memory usage: 825.8+ KB
# ...

# %%
top_countries= df['country'].value_counts().head(10)
print(top_countries)

import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,6))
sns.barplot(x=top_countries.values, y=top_countries.index, palette="Reds_r")
plt.title("Top 10 Content-Producing Countries", fontsize=14)
plt.xlabel("Number of Titles")
plt.ylabel("Country")
plt.show()
# Out:
# country
# United States     2818
# India              972
# Unknown            831
# United Kingdom     419
# Japan              245
# South Korea        199
# Canada             181
# Spain              145
# France             124
# Mexico             110
# Name: count, dtype: int64
# C:\Users\Default.DESKTOP-IT4P83D\AppData\Local\Temp\ipykernel_13392\138137636.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_countries.values, y=top_countries.index, palette="Reds_r")

# %%
df['listed_in'] = df['listed_in'].fillna('').astype(str).str.split(r',\s*')
genres= df.explode('listed_in', ignore_index=True)
genres= genres[genres['listed_in'].str.len()>0]

country_genre_counts= genres.groupby(['country', 'listed_in']).size().reset_index(name= 'count')
country_genre_counts.sort_values('count', ascending=False).head(15)
# Out:
#              country                       listed_in  count
# 1210           India      "'International Movies']"]    508
# 1248           India                    ["['Dramas'"    383
# 3094   United States                    ["['Dramas'"    288
# 1209           India        "'International Movies'"    271
# 1243           India                  ["['Comedies'"    262
# 3086   United States                  ["['Comedies'"    254
# 3091   United States           ["['Documentaries']"]    249
# 1203           India                      "'Dramas'"    212
# 3112   United States         ["['Stand-Up Comedy']"]    209
# 2659  United Kingdom          ["['British TV Shows'"    196
# 3034   United States        "'Independent Movies']"]    194
# 3076   United States        ["['Action & Adventure'"    185
# 3082   United States  ["['Children & Family Movies'"    176
# 3047   United States           "'Romantic Movies']"]    163
# 3718         Unknown    ["['International TV Shows'"    158

# %%
pivot_table= country_genre_counts.pivot_table(index= 'country', columns= 'listed_in', values= 'count', fill_value= 0)

top10_countries= df['country'].value_counts().head(10).index
pivot_top= pivot_table.loc[top10_countries]

plt.figure(figsize=(14,6))
sns.heatmap(pivot_top, cmap="YlOrRd", linewidths=0.5)
plt.title("Most Common Genres By Country", fontsize=14)
plt.xlabel("Genre")
plt.ylabel("Country")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 6
#       3 top10_countries= df['country'].value_counts().head(10).index
#       4 pivot_top= pivot_table.loc[top10_countries]
# ----> 6 plt.figure(14,6)
#       7 sns.heatmap(pivot_top, cmap="YlOrRd", linewidths=0.5)
#       8 plt.title("Most Common Genres By Country", fontsize=14)
#
# File c:\Users\Default.DESKTOP-IT4P83D\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\pyplot.py:1041, in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#    1031 if len(allnums) == max_open_warning >= 1:
#    1032     _api.warn_external(
#    1033         f"More than {max_open_warning} figures have been opened. "
#    1034         f"Figures created through the pyplot interface "
#    (...)   1038         f"Consider using `matplotlib.pyplot.close()`.",
# ...
